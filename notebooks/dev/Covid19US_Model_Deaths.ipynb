# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
import pandas as pd
import seaborn as sns
from pylab import rcParams
import matplotlib.pyplot as plt
from matplotlib import rc
from sklearn.model_selection import train_test_split
from pandas.plotting import register_matplotlib_converters

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

register_matplotlib_converters()
sns.set(style='whitegrid', palette='muted', font_scale=1.5)

rcParams['figure.figsize'] = 22, 10

RANDOM_SEED = 42

np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)

# %%
data = pd.read_csv('data/us-data.csv', thousands=',')
data
# Out:
#          Date  States  Positive  Negative  Pending  Hospitalized – Currently  \
# 0    20200725      56   4158341  46477342   3377.0                   59227.0
# 1    20200724      56   4092928  45745166   3409.0                   59670.0
# 2    20200723      56   4017735  44890521   3179.0                   59885.0
# 3    20200722      56   3946708  44137149   3051.0                   59675.0
# 4    20200721      56   3877558  43410797   3197.0                   59362.0
# ..        ...     ...       ...       ...      ...                       ...
# 181  20200126       1         2         0      NaN                       NaN
# 182  20200125       1         2         0      NaN                       NaN
# 183  20200124       1         2         0      NaN                       NaN
# 184  20200123       1         2         0      NaN                       NaN
# 185  20200122       1         2         0      NaN                       NaN
#
#      Hospitalized – Cumulative  In ICU – Currently  In ICU – Cumulative  \
# 0                     291347.0             10380.0              13279.0
# 1                     289355.0             10405.0              13182.0
# 2                     286329.0             10418.0              12933.0
# 3                     283829.0             10457.0              12790.0
# 4                     281581.0              6711.0              12629.0
# ..                         ...                 ...                  ...
# 181                        NaN                 NaN                  NaN
# 182                        NaN                 NaN                  NaN
# 183                        NaN                 NaN                  NaN
# 184                        NaN                 NaN                  NaN
# 185                        NaN                 NaN                  NaN
#
#      On Ventilator – Currently  On Ventilator – Cumulative  Recovered  \
# 0                       2729.0                      1300.0  1279414.0
# 1                       2712.0                      1297.0  1261624.0
# 2                       2472.0                      1280.0  1233269.0
# 3                       2440.0                      1258.0  1210849.0
# 4                       2414.0                      1242.0  1182931.0
# ..                         ...                         ...        ...
# 181                        NaN                         NaN        NaN
# 182                        NaN                         NaN        NaN
# 183                        NaN                         NaN        NaN
# 184                        NaN                         NaN        NaN
# 185                        NaN                         NaN        NaN
#
#        Deaths
# 0    138692.0
# 1    137655.0
# 2    136477.0
# 3    135438.0
# 4    134321.0
# ..        ...
# 181       NaN
# 182       NaN
# 183       NaN
# 184       NaN
# 185       NaN
#
# [186 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['Date', 'States', 'Positive', 'Negative', 'Pending',
#        'Hospitalized – Currently', 'Hospitalized – Cumulative',
#        'In ICU – Currently', 'In ICU – Cumulative',
#        'On Ventilator – Currently', 'On Ventilator – Cumulative', 'Recovered',
#        'Deaths'],
#       dtype='object')

# %%
data_cases = data[['Date','Positive']]
data_deaths = data[['Date', 'Positive', 'Hospitalized – Cumulative','In ICU – Cumulative','On Ventilator – Cumulative', 'Deaths']]
data_deaths
# Out:
#          Date  Positive  Hospitalized – Cumulative  In ICU – Cumulative  \
# 0    20200725   4158341                   291347.0              13279.0
# 1    20200724   4092928                   289355.0              13182.0
# 2    20200723   4017735                   286329.0              12933.0
# 3    20200722   3946708                   283829.0              12790.0
# 4    20200721   3877558                   281581.0              12629.0
# ..        ...       ...                        ...                  ...
# 181  20200126         2                        NaN                  NaN
# 182  20200125         2                        NaN                  NaN
# 183  20200124         2                        NaN                  NaN
# 184  20200123         2                        NaN                  NaN
# 185  20200122         2                        NaN                  NaN
#
#      On Ventilator – Cumulative    Deaths
# 0                        1300.0  138692.0
# 1                        1297.0  137655.0
# 2                        1280.0  136477.0
# 3                        1258.0  135438.0
# 4                        1242.0  134321.0
# ..                          ...       ...
# 181                         NaN       NaN
# 182                         NaN       NaN
# 183                         NaN       NaN
# 184                         NaN       NaN
# 185                         NaN       NaN
#
# [186 rows x 6 columns]

# %%
data_deaths['Date'] = pd.to_datetime(data_deaths['Date'].astype(str), format='%Y%m%d')
data_deaths = data_deaths.sort_values(by=['Date'], ascending=True)
data_deaths
# Out:
#           Date  Positive  Hospitalized – Cumulative  In ICU – Cumulative  \
# 185 2020-01-22         2                        NaN                  NaN
# 184 2020-01-23         2                        NaN                  NaN
# 183 2020-01-24         2                        NaN                  NaN
# 182 2020-01-25         2                        NaN                  NaN
# 181 2020-01-26         2                        NaN                  NaN
# ..         ...       ...                        ...                  ...
# 4   2020-07-21   3877558                   281581.0              12629.0
# 3   2020-07-22   3946708                   283829.0              12790.0
# 2   2020-07-23   4017735                   286329.0              12933.0
# 1   2020-07-24   4092928                   289355.0              13182.0
# 0   2020-07-25   4158341                   291347.0              13279.0
#
#      On Ventilator – Cumulative    Deaths
# 185                         NaN       NaN
# 184                         NaN       NaN
# 183                         NaN       NaN
# 182                         NaN       NaN
# 181                         NaN       NaN
# ..                          ...       ...
# 4                        1242.0  134321.0
# 3                        1258.0  135438.0
# 2                        1280.0  136477.0
# 1                        1297.0  137655.0
# 0                        1300.0  138692.0
#
# [186 rows x 6 columns]

# %%
# Convert the date column to datetime
data_deaths['Date'] = pd.to_datetime(data_deaths['Date'])

# Set the index of the DataFrame to the date column
data_deaths.set_index('Date', inplace = True)
data_deaths.sort_index(ascending=True)

# Print DataFrame summary
data_deaths.info()

# Print DataFrame
data_deaths
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 186 entries, 2020-01-22 to 2020-07-25
# Data columns (total 5 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Positive                    186 non-null    int64
#  1   Hospitalized – Cumulative   144 non-null    float64
#  2   In ICU – Cumulative         123 non-null    float64
#  3   On Ventilator – Cumulative  116 non-null    float64
#  4   Deaths                      151 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 8.7 KB
#             Positive  Hospitalized – Cumulative  In ICU – Cumulative  \
# Date
# 2020-01-22         2                        NaN                  NaN
# 2020-01-23         2                        NaN                  NaN
# 2020-01-24         2                        NaN                  NaN
# 2020-01-25         2                        NaN                  NaN
# 2020-01-26         2                        NaN                  NaN
# ...              ...                        ...                  ...
# 2020-07-21   3877558                   281581.0              12629.0
# 2020-07-22   3946708                   283829.0              12790.0
# 2020-07-23   4017735                   286329.0              12933.0
# 2020-07-24   4092928                   289355.0              13182.0
# 2020-07-25   4158341                   291347.0              13279.0
#
#             On Ventilator – Cumulative    Deaths
# Date
# 2020-01-22                         NaN       NaN
# 2020-01-23                         NaN       NaN
# 2020-01-24                         NaN       NaN
# 2020-01-25                         NaN       NaN
# 2020-01-26                         NaN       NaN
# ...                                ...       ...
# 2020-07-21                      1242.0  134321.0
# 2020-07-22                      1258.0  135438.0
# 2020-07-23                      1280.0  136477.0
# 2020-07-24                      1297.0  137655.0
# 2020-07-25                      1300.0  138692.0
#
# [186 rows x 5 columns]

# %%
# Plot the series
data_deaths.plot()

# %%
data_deaths.fillna(0, inplace=True)
data_deaths
# Out:
#             Positive  Hospitalized – Cumulative  In ICU – Cumulative  \
# Date
# 2020-01-22         2                        0.0                  0.0
# 2020-01-23         2                        0.0                  0.0
# 2020-01-24         2                        0.0                  0.0
# 2020-01-25         2                        0.0                  0.0
# 2020-01-26         2                        0.0                  0.0
# ...              ...                        ...                  ...
# 2020-07-21   3877558                   281581.0              12629.0
# 2020-07-22   3946708                   283829.0              12790.0
# 2020-07-23   4017735                   286329.0              12933.0
# 2020-07-24   4092928                   289355.0              13182.0
# 2020-07-25   4158341                   291347.0              13279.0
#
#             On Ventilator – Cumulative    Deaths
# Date
# 2020-01-22                         0.0       0.0
# 2020-01-23                         0.0       0.0
# 2020-01-24                         0.0       0.0
# 2020-01-25                         0.0       0.0
# 2020-01-26                         0.0       0.0
# ...                                ...       ...
# 2020-07-21                      1242.0  134321.0
# 2020-07-22                      1258.0  135438.0
# 2020-07-23                      1280.0  136477.0
# 2020-07-24                      1297.0  137655.0
# 2020-07-25                      1300.0  138692.0
#
# [186 rows x 5 columns]

# %%
train_size = int(len(data_deaths) * 0.9)
test_size = len(data_deaths) - train_size

train, test = data_deaths[0:train_size], data_deaths[train_size:len(data_deaths)]
print(len(train), len(test))
# Out:
# 167 19

# %%
from sklearn.preprocessing import RobustScaler

f_columns = ['Positive', 'Hospitalized – Cumulative','In ICU – Cumulative','On Ventilator – Cumulative']

f_transformer = RobustScaler()
cnt_transformer = RobustScaler()

f_transformer = f_transformer.fit(train[f_columns].to_numpy())
cnt_transformer = cnt_transformer.fit(train[['Deaths']])

train.loc[:, f_columns] = f_transformer.transform(train[f_columns].to_numpy())
train['Deaths'] = cnt_transformer.transform(train[['Deaths']])

test.loc[:, f_columns] = f_transformer.transform(test[f_columns].to_numpy())
test['Deaths'] = cnt_transformer.transform(test[['Deaths']])

# %%
def create_dataset(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        v = X.iloc[i:(i + time_steps)].values
        Xs.append(v)        
        ys.append(y.iloc[i + time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps = 10

# reshape to [samples, time_steps, n_features]

X_train, y_train = create_dataset(train, train.Deaths, time_steps)
X_test, y_test = create_dataset(test, test.Deaths, time_steps)

print(X_train.shape, y_train.shape)
# Out:
# (157, 10, 5) (157,)

# %%
model = keras.Sequential()
model.add(
  keras.layers.Bidirectional(
    keras.layers.LSTM(
      units=128, 
      input_shape=(X_train.shape[1], X_train.shape[2])
    )
  )
)
model.add(keras.layers.Dropout(rate=0.2))
model.add(keras.layers.Dense(units=1))
model.compile(loss='mean_squared_error', optimizer='adam')

# %%
history = model.fit(
    X_train, y_train, 
    epochs=100, 
    batch_size=32, 
    validation_split=0.1,
    shuffle=False
)
# Out:
# Epoch 1/100
# WARNING:tensorflow:Layer bidirectional_13 is casting an input tensor from dtype float64 to the layer's dtype of float32, which is new behavior in TensorFlow 2.  The layer has dtype float32 because it's dtype defaults to floatx.
#
# If you intended to run this layer in float32, you can safely ignore this warning. If in doubt, this warning is likely only an issue if you are porting a TensorFlow 1.X model to TensorFlow 2.
#
# To change all layers to have dtype float64 by default, call `tf.keras.backend.set_floatx('float64')`. To change just this layer, pass dtype='float64' to the layer constructor. If you are the author of this layer, you can disable autocasting by passing autocast=False to the base Layer constructor.
#
# 5/5 [==============================] - 1s 290ms/step - loss: 0.0558 - val_loss: 0.0351
# Epoch 2/100
# 5/5 [==============================] - 0s 26ms/step - loss: 0.0789 - val_loss: 0.1323
# Epoch 3/100
# 5/5 [==============================] - 0s 28ms/step - loss: 0.0178 - val_loss: 0.0418
# Epoch 4/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0271 - val_loss: 0.0659
# Epoch 5/100
# 5/5 [==============================] - 0s 29ms/step - loss: 0.0115 - val_loss: 0.0013
# Epoch 6/100
# 5/5 [==============================] - 0s 30ms/step - loss: 0.0042 - val_loss: 0.0268
# Epoch 7/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0064 - val_loss: 0.0274
# Epoch 8/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0032 - val_loss: 0.0021
# Epoch 9/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0036 - val_loss: 0.0024
# Epoch 10/100
# 5/5 [==============================] - 0s 31ms/step - loss: 0.0044 - val_loss: 7.7971e-04
# Epoch 11/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0030 - val_loss: 0.0015
# Epoch 12/100
# 5/5 [==============================] - 0s 32ms/step - loss: 0.0019 - val_loss: 0.0072
# Epoch 13/100
# 5/5 [==============================] - 0s 55ms/step - loss: 0.0026 - val_loss: 0.0054
# Epoch 14/100
# 5/5 [==============================] - 0s 39ms/step - loss: 0.0020 - val_loss: 3.0199e-04
# Epoch 15/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0019 - val_loss: 4.9446e-04
# Epoch 16/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0023 - val_loss: 1.4470e-04
# Epoch 17/100
# 5/5 [==============================] - 0s 38ms/step - loss: 0.0020 - val_loss: 6.9935e-04
# Epoch 18/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0019 - val_loss: 0.0026
# Epoch 19/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0017 - val_loss: 0.0015
# Epoch 20/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0014 - val_loss: 4.9329e-04
# Epoch 21/100
# 5/5 [==============================] - 0s 40ms/step - loss: 0.0016 - val_loss: 1.3011e-04
# Epoch 22/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0015 - val_loss: 9.1502e-05
# Epoch 23/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0010 - val_loss: 1.4490e-04
# Epoch 24/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0016 - val_loss: 1.5097e-04
# Epoch 25/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0010 - val_loss: 8.9550e-05
# Epoch 26/100
# 5/5 [==============================] - 0s 54ms/step - loss: 0.0017 - val_loss: 1.0317e-04
# Epoch 27/100
# 4/5 [=======================>......] - ETA: 0s - loss: 0.0015/5 [==============================] - 0s 64ms/step - loss: 0.0014 - val_loss: 1.5274e-04
# Epoch 28/100
# 5/5 [==============================] - 0s 57ms/step - loss: 0.0014 - val_loss: 9.8338e-05
# Epoch 29/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0011 - val_loss: 2.2845e-04
# Epoch 30/100
# 5/5 [==============================] - 0s 47ms/step - loss: 0.0014 - val_loss: 7.9050e-05
# Epoch 31/100
# 5/5 [==============================] - 0s 52ms/step - loss: 0.0012 - val_loss: 8.6973e-05
# Epoch 32/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0011 - val_loss: 7.7566e-05
# Epoch 33/100
# 5/5 [==============================] - 0s 48ms/step - loss: 9.3910e-04 - val_loss: 3.3402e-04
# Epoch 34/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0010 - val_loss: 2.2688e-04
# Epoch 35/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0012 - val_loss: 2.3147e-04
# Epoch 36/100
# 5/5 [==============================] - 0s 60ms/step - loss: 0.0011 - val_loss: 2.9797e-04
# Epoch 37/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0016 - val_loss: 2.0393e-04
# Epoch 38/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.7582e-04 - val_loss: 3.3383e-04
# Epoch 39/100
# 5/5 [==============================] - 0s 46ms/step - loss: 9.8625e-04 - val_loss: 3.9187e-04
# Epoch 40/100
# 5/5 [==============================] - 0s 50ms/step - loss: 9.6916e-04 - val_loss: 1.0091e-04
# Epoch 41/100
# 5/5 [==============================] - 0s 51ms/step - loss: 0.0013 - val_loss: 7.9319e-05
# Epoch 42/100
# 5/5 [==============================] - 0s 45ms/step - loss: 0.0010 - val_loss: 9.0588e-05
# Epoch 43/100
# 5/5 [==============================] - 0s 42ms/step - loss: 8.4919e-04 - val_loss: 1.8430e-04
# Epoch 44/100
# 5/5 [==============================] - 0s 38ms/step - loss: 9.0050e-04 - val_loss: 1.6816e-04
# Epoch 45/100
# 5/5 [==============================] - 0s 37ms/step - loss: 9.9188e-04 - val_loss: 1.5642e-04
# Epoch 46/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.3414e-04 - val_loss: 7.8033e-05
# Epoch 47/100
# 5/5 [==============================] - 0s 42ms/step - loss: 0.0011 - val_loss: 4.1326e-04
# Epoch 48/100
# 5/5 [==============================] - 0s 37ms/step - loss: 0.0010 - val_loss: 1.9568e-04
# Epoch 49/100
# 5/5 [==============================] - 0s 41ms/step - loss: 0.0011 - val_loss: 1.8594e-04
# Epoch 50/100
# 5/5 [==============================] - 0s 42ms/step - loss: 9.4940e-04 - val_loss: 8.5432e-05
# Epoch 51/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.4423e-04 - val_loss: 0.0024
# Epoch 52/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0013 - val_loss: 2.7458e-04
# Epoch 53/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0013 - val_loss: 3.8655e-04
# Epoch 54/100
# 5/5 [==============================] - 0s 45ms/step - loss: 5.9467e-04 - val_loss: 0.0020
# Epoch 55/100
# 5/5 [==============================] - 0s 44ms/step - loss: 0.0010 - val_loss: 0.0011
# Epoch 56/100
# 5/5 [==============================] - 0s 50ms/step - loss: 0.0011 - val_loss: 1.5790e-04
# Epoch 57/100
# 5/5 [==============================] - 0s 61ms/step - loss: 0.0011 - val_loss: 3.3185e-04
# Epoch 58/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.6134e-04 - val_loss: 7.2886e-04
# Epoch 59/100
# 5/5 [==============================] - 0s 59ms/step - loss: 8.9784e-04 - val_loss: 1.5932e-04
# Epoch 60/100
# 5/5 [==============================] - 0s 75ms/step - loss: 0.0012 - val_loss: 9.5073e-05
# Epoch 61/100
# 5/5 [==============================] - 0s 48ms/step - loss: 0.0011 - val_loss: 0.0030
# Epoch 62/100
# 5/5 [==============================] - 0s 46ms/step - loss: 8.2369e-04 - val_loss: 7.6958e-05
# Epoch 63/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0011 - val_loss: 8.1942e-04
# Epoch 64/100
# 5/5 [==============================] - 0s 45ms/step - loss: 8.7577e-04 - val_loss: 1.4177e-04
# Epoch 65/100
# 5/5 [==============================] - 0s 44ms/step - loss: 8.0998e-04 - val_loss: 1.4826e-04
# Epoch 66/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.8823e-04 - val_loss: 1.2199e-04
# Epoch 67/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.8046e-04 - val_loss: 0.0013
# Epoch 68/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.0329e-04 - val_loss: 8.9883e-05
# Epoch 69/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.5276e-04 - val_loss: 1.2075e-04
# Epoch 70/100
# 5/5 [==============================] - 0s 43ms/step - loss: 8.9315e-04 - val_loss: 4.6795e-04
# Epoch 71/100
# 5/5 [==============================] - 0s 43ms/step - loss: 5.1630e-04 - val_loss: 9.3730e-05
# Epoch 72/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.0513e-04 - val_loss: 2.5192e-04
# Epoch 73/100
# 5/5 [==============================] - 0s 42ms/step - loss: 5.0772e-04 - val_loss: 2.5012e-04
# Epoch 74/100
# 5/5 [==============================] - 0s 44ms/step - loss: 5.7212e-04 - val_loss: 6.8608e-04
# Epoch 75/100
# 5/5 [==============================] - 0s 41ms/step - loss: 6.6658e-04 - val_loss: 2.7548e-04
# Epoch 76/100
# 5/5 [==============================] - 0s 42ms/step - loss: 7.4344e-04 - val_loss: 8.2644e-05
# Epoch 77/100
# 5/5 [==============================] - 0s 35ms/step - loss: 6.5676e-04 - val_loss: 2.4986e-04
# Epoch 78/100
# 5/5 [==============================] - 0s 36ms/step - loss: 6.2762e-04 - val_loss: 7.8488e-05
# Epoch 79/100
# 5/5 [==============================] - 0s 35ms/step - loss: 6.1824e-04 - val_loss: 5.5367e-04
# Epoch 80/100
# 5/5 [==============================] - 0s 40ms/step - loss: 6.1232e-04 - val_loss: 4.0984e-04
# Epoch 81/100
# 5/5 [==============================] - 0s 44ms/step - loss: 6.6071e-04 - val_loss: 3.9176e-04
# Epoch 82/100
# 5/5 [==============================] - 0s 48ms/step - loss: 7.1943e-04 - val_loss: 1.1821e-04
# Epoch 83/100
# 5/5 [==============================] - 0s 45ms/step - loss: 6.9843e-04 - val_loss: 1.9850e-04
# Epoch 84/100
# 5/5 [==============================] - 0s 49ms/step - loss: 5.2336e-04 - val_loss: 2.1530e-04
# Epoch 85/100
# 5/5 [==============================] - 0s 45ms/step - loss: 5.6671e-04 - val_loss: 7.9933e-05
# Epoch 86/100
# 5/5 [==============================] - 0s 45ms/step - loss: 4.4908e-04 - val_loss: 1.0174e-04
# Epoch 87/100
# 5/5 [==============================] - 0s 45ms/step - loss: 5.7577e-04 - val_loss: 5.3255e-04
# Epoch 88/100
# 5/5 [==============================] - 0s 47ms/step - loss: 6.1762e-04 - val_loss: 8.3371e-05
# Epoch 89/100
# 5/5 [==============================] - 0s 45ms/step - loss: 7.0212e-04 - val_loss: 5.2869e-04
# Epoch 90/100
# 5/5 [==============================] - 0s 47ms/step - loss: 7.4362e-04 - val_loss: 1.8218e-04
# Epoch 91/100
# 5/5 [==============================] - 0s 46ms/step - loss: 0.0011 - val_loss: 5.7174e-04
# Epoch 92/100
# 5/5 [==============================] - 0s 50ms/step - loss: 6.3056e-04 - val_loss: 3.8250e-04
# Epoch 93/100
# 5/5 [==============================] - 0s 55ms/step - loss: 5.9170e-04 - val_loss: 3.0760e-04
# Epoch 94/100
# 5/5 [==============================] - 0s 56ms/step - loss: 4.5562e-04 - val_loss: 1.8800e-04
# Epoch 95/100
# 5/5 [==============================] - 0s 68ms/step - loss: 4.4907e-04 - val_loss: 8.4820e-05
# Epoch 96/100
# 5/5 [==============================] - 0s 57ms/step - loss: 7.2875e-04 - val_loss: 5.2078e-04
# Epoch 97/100
# 5/5 [==============================] - 0s 52ms/step - loss: 7.9518e-04 - val_loss: 1.3622e-04
# Epoch 98/100
# 5/5 [==============================] - 0s 54ms/step - loss: 5.7492e-04 - val_loss: 1.9989e-04
# Epoch 99/100
# 5/5 [==============================] - 0s 46ms/step - loss: 6.5262e-04 - val_loss: 9.0689e-05
# Epoch 100/100
# 5/5 [==============================] - 0s 46ms/step - loss: 7.0390e-04 - val_loss: 9.2332e-05

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend();

# %%
y_pred = model.predict(X_test)

# %%
y_train_inv = cnt_transformer.inverse_transform(y_train.reshape(1, -1))
y_test_inv = cnt_transformer.inverse_transform(y_test.reshape(1, -1))
y_pred_inv = cnt_transformer.inverse_transform(y_pred)
print(y_pred_inv.reshape(1, -1) - y_test_inv)
print(y_test_inv)
# Out:
# [[2453.71875  2539.328125 2980.5625   3505.375    3343.5      3053.5625
#   2882.46875  2587.890625 2485.34375 ]]
# [[131523. 132395. 132921. 133283. 134321. 135438. 136477. 137655. 138692.]]

# %%
plt.plot(np.arange(0, len(y_train)), y_train_inv.flatten(), 'g', label="history")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_test_inv.flatten(), marker='.', label="true")
plt.plot(np.arange(len(y_train), len(y_train) + len(y_test)), y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Deaths Count')
plt.xlabel('Days')
plt.legend()
plt.show();

# %%
plt.plot(y_test_inv.flatten(), marker='.', label="true")
plt.plot(y_pred_inv.flatten(), 'r', label="prediction")
plt.ylabel('Deaths Count')
plt.xlabel('Days Step')
plt.legend()
plt.show();

# %%
# calculate RMSE
from math import sqrt
rmse = sqrt(mean_squared_error(y_test_inv, y_pred_inv.reshape(1, -1)))
print('Test RMSE: %.3f' % rmse)
print('Accuracy: %.2f' % (100 - rmse / np.mean(y_test_inv)))
# Out:
# Test RMSE: 2893.024
# Accuracy: 99.98
